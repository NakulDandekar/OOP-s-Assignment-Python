# %% [markdown]
# # Assignment No.5

# %% [markdown]
# ## OPPs

# %%
#What are the five key concepts of Object-Oriented Programming (OOP)?
'''
The five key concepts of OOP are:

1.Class and Object: A class is a blueprint for objects, and objects are instances of classes.
2.Encapsulation: Bundling data and methods into a single unit, with restricted access to protect object integrity.
3.Inheritance: A class inherits properties and behaviors from another class, enabling code reuse.
4.Polymorphism: Objects can be treated as instances of their parent class, allowing methods to behave differently based on the object.
5.Abstraction: Hiding complex details and exposing only the essential features, simplifying object interaction.
'''
# Out:
# '\nThe five key concepts of OOP are:\n\n1.Class and Object: A class is a blueprint for objects, and objects are instances of classes.\n2.Encapsulation: Bundling data and methods into a single unit, with restricted access to protect object integrity.\n3.Inheritance: A class inherits properties and behaviors from another class, enabling code reuse.\n4.Polymorphism: Objects can be treated as instances of their parent class, allowing methods to behave differently based on the object.\n5.Abstraction: Hiding complex details and exposing only the essential features, simplifying object interaction.\n'

# %%
#Write a Python class for a `Car` with attributes for `make`, `model`, and `year`. Include a method to display the car's information.
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def display_info(self):
        print(f"Car Information: {self.year} {self.make} {self.model}")
        
my_car = Car("Toyota", "Corolla", 2020)
my_car.display_info()
# Out:
# Car Information: 2020 Toyota Corolla

# %%
# Explain the difference between instance methods and class methods. Provide an example of each.
'''
1. Instance Methods:
>>Belong to the instance of a class.
>>They can access and modify instance-specific data (attributes).
>>The first parameter is always self, which refers to the current instance of the class.
Example:
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def display_info(self):
        print(f"Car: {self.year} {self.make} {self.model}")


my_car = Car("Tesla", "Model S", 2022)
my_car.display_info()  # Output: Car: 2022 Tesla Model S


2. Class Methods:
>>Belong to the class itself rather than any particular instance.
>>They can't access instance-specific data but can access and modify class-level data.
>>The first parameter is cls, which refers to the class itself.
>>They are decorated with @classmethod.
Example:
class Car:
    total_cars = 0  
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        Car.total_cars += 1

    @classmethod
    def display_total_cars(cls):
        print(f"Total cars created: {cls.total_cars}")


car1 = Car("Toyota", "Camry", 2020)
car2 = Car("Honda", "Accord", 2021)

Car.display_total_cars() 


'''

# %%
#How does Python implement method overloading? Give an example.
'''
In Python, method overloading (the ability to define multiple methods with the same name but different parameters) is not natively supported like in some other languages such as Java or C++. However, you can achieve similar behavior using default arguments or by handling different parameter types/values within a single method.

Python's approach to method overloading:
>>Default Arguments: Define default values for parameters, so the method can be called with varying numbers of arguments.
>>Variable-length Arguments: Use *args or **kwargs to accept an arbitrary number of arguments.

Example:
>>(using default arguments)
class Calculator:
    def add(self, a, b=0, c=0):
        return a + b + c

calc = Calculator()

print(calc.add(5))        
print(calc.add(5, 10))     
print(calc.add(5, 10, 15)) 


>>(using variable-length arguments (*args)):
class Calculator:
    def add(self, *args):
        return sum(args)

calc = Calculator()

print(calc.add(5))            
print(calc.add(5, 10))        
print(calc.add(5, 10, 15))   
print(calc.add(1, 2, 3, 4))   

    In Python, instead of defining multiple methods with the same name but different parameters, you typically implement this functionality within a single method by checking the number or type of arguments passed.








'''

# %%
# What are the three types of access modifiers in Python? How are they denoted?
'''
>>Public, Protected, Private are the three types of access modifiers.
In Python, the three access modifiers are:

1. Public: No prefix. Accessible from outside the class.
2. Protected: Single underscore prefix (`_`). Intended for internal use and subclasses.
3. Private: Double underscore prefix (`__`). Name-mangled and intended to be private to the class.

'''

# %%
#Describe the five types of inheritance in Python. Provide a simple example of multiple inheritance.
'''
1.Single Inheritance:

A subclass inherits from a single superclass.
Example:
class Parent:
    def speak(self):
        print("Parent speaking")

class Child(Parent):
    def play(self):
        print("Child playing")

obj = Child()
obj.speak()  
obj.play()  

2.Multiple Inheritance:

A subclass inherits from more than one superclass.

Example:

class Father:
    def drive(self):
        print("Father driving")

class Mother:
    def cook(self):
        print("Mother cooking")

class Child(Father, Mother):
    def study(self):
        print("Child studying")

obj = Child()
obj.drive()  
obj.cook()   
obj.study()  

3.Multilevel Inheritance:

A subclass inherits from another subclass, forming a chain.

Example:

class Grandparent:
    def wisdom(self):
        print("Grandparent's wisdom")

class Parent(Grandparent):
    def guidance(self):
        print("Parent's guidance")

class Child(Parent):
    def learning(self):
        print("Child's learning")

obj = Child()
obj.wisdom()    
obj.guidance()  
obj.learning()  

4.Hierarchical Inheritance:

Multiple subclasses inherit from a single superclass.

Example:
class Animal:
    def eat(self):
        print("Animal eating")

class Dog(Animal):
    def bark(self):
        print("Dog barking")

class Cat(Animal):
    def meow(self):
        print("Cat meowing")

dog = Dog()
cat = Cat()
dog.eat()  
cat.eat()  

5.Hybrid Inheritance:

A combination of two or more types of inheritance, often leading to complex inheritance hierarchies.

Example:
class A:
    def method_a(self):
        print("Method A")

class B(A):
    def method_b(self):
        print("Method B")

class C(A):
    def method_c(self):
        print("Method C")

class D(B, C):
    def method_d(self):
        print("Method D")

obj = D()
obj.method_a()  
obj.method_b()  
obj.method_c()  
obj.method_d()  
'''

# %%
# What is the Method Resolution Order (MRO) in Python? How can you retrieve it programmatically?
'''
The Method Resolution Order (MRO) in Python is the order in which classes are looked up when searching for a method or attribute. It determines the sequence in which base classes are considered when resolving method calls, particularly in the context of multiple inheritance.

How MRO Works:
Python uses the C3 linearization algorithm to determine the MRO. This algorithm ensures a consistent and predictable method resolution order even in complex inheritance hierarchies.
The MRO is important for determining which method will be called when a method is invoked on an instance of a class.

Retrieving MRO Programmatically:
You can retrieve the MRO of a class using the __mro__ attribute or the mro() method.

Using __mro__:
class A:
    pass

class B(A):
    pass

class C(A):
    pass

class D(B, C):
    pass

print(D.__mro__)  

Using mro() Method:
class A:
    pass

class B(A):
    pass

class C(A):
    pass

class D(B, C):
    pass

print(D.mro()) 

Summary:
MRO defines the order in which base classes are considered for method resolution.
Use __mro__ attribute or mro() method to retrieve the MRO of a class programmatically.
'''

# %%
#Create an abstract base class `Shape` with an abstract method `area()`. Then create two subclasses `Circle` and `Rectangle` that implement the `area()` method.
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

circle = Circle(5)
print(f"Circle area: {circle.area()}")  

rectangle = Rectangle(4, 6)
print(f"Rectangle area: {rectangle.area()}")
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %%
# Demonstrate polymorphism by creating a function that can work with different shape objects to calculate and print their areas.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

def print_area(shape: Shape):
    print(f"The area of the shape is: {shape.area()}")

circle = Circle(5)
rectangle = Rectangle(4, 6)

print_area(circle)     
print_area(rectangle)
# Out:
# The area of the shape is: 78.53981633974483
# The area of the shape is: 24

# %%
# Implement encapsulation in a `BankAccount` class with private attributes for `balance` and `account_number`. Include methods for deposit, withdrawal, and balance inquiry.
    
class BankAccount:
    def __init__(self, account_number, initial_balance=0):
        self.__account_number = account_number  
        self.__balance = initial_balance        

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}.")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"Withdrew ${amount}. New balance: ${self.__balance}.")
            else:
                print("Insufficient funds.")
        else:
            print("Withdrawal amount must be positive.")

    def get_balance(self):
        return self.__balance

    def get_account_number(self):
        return self.__account_number

account = BankAccount("123456789", 1000)

print(f"Account Number: {account.get_account_number()}")
print(f"Initial Balance: ${account.get_balance()}")

account.deposit(500)      
account.withdraw(200)     
print(f"Final Balance: ${account.get_balance()}")
# Out:
# Account Number: 123456789
# Initial Balance: $1000
# Deposited $500. New balance: $1500.
# Withdrew $200. New balance: $1300.
# Final Balance: $1300

# %%
#Write a class that overrides the `__str__` and `__add__` magic methods. What will these methods allow you to do?
'''
1.__str__ Method:
Purpose: This method is used to define the string representation of an object. It’s called by the str() function and when you use print() on an object.
Example:

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Point({self.x}, {self.y})"

p = Point(3, 4)
print(p)  

2.__add__ Method:
Purpose: This method allows you to define how the + operator behaves for instances of your class. It’s used to perform addition operations with objects of your class.

Example:
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Point({self.x}, {self.y})"

    def __add__(self, other):
        if isinstance(other, Point):
            return Point(self.x + other.x, self.y + other.y)
        return NotImplemented


p1 = Point(1, 2)
p2 = Point(3, 4)
p3 = p1 + p2
print(p3)  


__str__: This method provides a human-readable string representation of the object, which is useful for printing and debugging.
__add__: This method allows you to define how addition works between two objects of the class. In this example, it adds the x and y coordinates of two Point objects and returns a new Point object with the result.
'''
# Out:
# '\n1.__str__ Method:\nPurpose: This method is used to define the string representation of an object. It’s called by the str() function and when you use print() on an object.\nExample:\n\nclass Point:\n    def __init__(self, x, y):\n        self.x = x\n        self.y = y\n\n    def __str__(self):\n        return f"Point({self.x}, {self.y})"\n\np = Point(3, 4)\nprint(p)  \n\n2.__add__ Method:\nPurpose: This method allows you to define how the + operator behaves for instances of your class. It’s used to perform addition operations with objects of your class.\n\nExample:\nclass Point:\n    def __init__(self, x, y):\n        self.x = x\n        self.y = y\n\n    def __str__(self):\n        return f"Point({self.x}, {self.y})"\n\n    def __add__(self, other):\n        if isinstance(other, Point):\n            return Point(self.x + other.x, self.y + other.y)\n        return NotImplemented\n\n\np1 = Point(1, 2)\np2 = Point(3, 4)\np3 = p1 + p2\nprint(p3)  \n\n\n__str__: This method provides a 
# ...

# %%
# Create a decorator that measures and prints the execution time of a function.
import time

def timing_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()  
        result = func(*args, **kwargs)  
        end_time = time.time()  
        execution_time = end_time - start_time  
        print(f"Execution time of {func.__name__}: {execution_time:.4f} seconds")
        return result
    return wrapper

@timing_decorator
def example_function(n):
    total = 0
    for i in range(n):
        total += i
    return total


result = example_function(1000000)
print(f"Result: {result}")
# Out:
# Execution time of example_function: 0.0683 seconds
# Result: 499999500000

# %%
#Explain the concept of the Diamond Problem in multiple inheritance. How does Python resolve it?
'''
The Diamond Problem occurs in multiple inheritance when a class inherits from two or more classes that have a common base class, leading to ambiguity in method resolution. This problem is named for the diamond-shaped inheritance diagram it creates.

Example of the Diamond Problem
class A:
    def method(self):
        print("Method in A")

class B(A):
    def method(self):
        print("Method in B")

class C(A):
    def method(self):
        print("Method in C")

class D(B, C):
    pass

d = D()
d.method()


Resolution in Python
Python resolves the Diamond Problem using the C3 Linearization Algorithm (also known as C3 superclass linearization). This algorithm provides a consistent method resolution order (MRO) that determines the order in which base classes are considered.

How Python Resolves It:

The MRO is computed in such a way that it respects the inheritance hierarchy and resolves ambiguities by following a specific order.
The MRO can be retrieved using the __mro__ attribute or the mro() method.

Example with Python's MRO
class A:
    def method(self):
        print("Method in A")

class B(A):
    def method(self):
        print("Method in B")

class C(A):
    def method(self):
        print("Method in C")

class D(B, C):
    pass


print(D.__mro__)  
print(D.mro())    

d = D()
d.method()  

The MRO for class D is determined to be [D, B, C, A, object]. This means that Python will first look for methods in D, then in B, then C, then A, and finally in object.
In the D class, when d.method() is called, Python looks for method() in D, then B, where it finds the method, and uses it. Hence, the output is Method in B.
This approach ensures that the method resolution order is consistent and avoids the ambiguities of the diamond problem.
'''

# %%
#Write a class method that keeps track of the number of instances created from a class.

class InstanceCounter:
    _instance_count = 0  

    def __init__(self):
        
        InstanceCounter._instance_count += 1

    @classmethod
    def get_instance_count(cls):
        
        return cls._instance_count


obj1 = InstanceCounter()
obj2 = InstanceCounter()
obj3 = InstanceCounter()

print(f"Number of instances created: {InstanceCounter.get_instance_count()}")
# Out:
# Number of instances created: 3

# %%
# Implement a static method in a class that checks if a given year is a leap year.
class YearUtils:
    @staticmethod
    def is_leap_year(year):
        if (year % 4 == 0):
            if (year % 100 != 0) or (year % 400 == 0):
                return True
        return False

year = 2024
print(f"Is {year} a leap year? {YearUtils.is_leap_year(year)}")  
year = 1900
print(f"Is {year} a leap year? {YearUtils.is_leap_year(year)}")
# Out:
# Is 2024 a leap year? True
# Is 1900 a leap year? False
